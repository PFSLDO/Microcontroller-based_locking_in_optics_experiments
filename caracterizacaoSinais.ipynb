# %% [markdown]
# # Caracterizacao dos Sinais 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataHorizontal = pd.read_csv('./1110_H.csv', sep = ",")
dataVertical = pd.read_csv('./1110_V.csv', sep = ",")

display(dataHorizontal)
display(dataVertical)
# Out:
#         Record Length             2500   Points  -247.19999731E-3  1.9399999  \
# 0     Sample Interval  199.99999495E-6        s           -0.2470       1.94
# 1       Trigger Point      1.2360001E3  Samples           -0.2468       2.00
# 2                 NaN              NaN      NaN           -0.2466       1.86
# 3                 NaN              NaN      NaN           -0.2464       1.94
# 4                 NaN              NaN      NaN           -0.2462       1.96
# ...               ...              ...      ...               ...        ...
# 2494              NaN              NaN      NaN            0.2518       1.72
# 2495              NaN              NaN      NaN            0.2520       1.86
# 2496              NaN              NaN      NaN            0.2522       1.88
# 2497              NaN              NaN      NaN            0.2524       1.98
# 2498              NaN              NaN      NaN            0.2526       2.02
#
# ...

# %%
tempo = dataHorizontal['-247.19999731E-3']
sinalAzul = dataHorizontal['1.9399999']
sinalAmarelo = dataHorizontal['23.00000000']

# Plotar o sinal original
plt.figure(figsize=(12, 5))
plt.plot(tempo, sinalAzul, label='Sinal de saída', color = 'b')
plt.plot(tempo, sinalAmarelo, label='Sinal de entrada', color = 'y')
plt.xlabel('Tempo')
plt.ylabel('Amplitude')
plt.title('Sinal de Tensão')
plt.legend()
plt.grid()
plt.show()

# Calcular a Transformada de Fourier
frequencia_amostragem = 1 / (tempo[1] - tempo[0])  # assumindo espaçamento constante
fft_sinalAzul = np.fft.fft(sinalAzul)
frequenciasAzul = np.fft.fftfreq(len(sinalAzul), d=1/frequencia_amostragem)
fft_sinalAmarelo = np.fft.fft(sinalAmarelo)
frequenciasAmarelo = np.fft.fftfreq(len(sinalAmarelo), d=1/frequencia_amostragem)

# Plotar a magnitude da Transformada de Fourier
plt.figure(figsize=(12, 5))
plt.plot(frequenciasAzul, np.abs(fft_sinalAzul), label='Transformada de Fourier azul', color = 'b')
plt.xlabel('Frequência (Hz)')
plt.ylabel('Magnitude')
plt.title('Espectro de Frequência')
plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(12, 5))
plt.plot(frequenciasAmarelo, np.abs(fft_sinalAmarelo), label='Transformada de Fourier amarelo', color = 'y')
plt.xlabel('Frequência (Hz)')
plt.ylabel('Magnitude')
plt.title('Espectro de Frequência')
plt.legend()
plt.grid()
plt.show()

# %%
tempo = dataVertical['-122.2000048E-3']
sinalAzul = dataVertical['1.3600000']
sinalAmarelo = dataVertical['26.80000114']

# Plotar o sinal original
plt.figure(figsize=(12, 5))
plt.plot(tempo, sinalAzul, label='Sinal de saída', color = 'b')
plt.plot(tempo, sinalAmarelo, label='Sinal de entrada', color = 'y')
plt.xlabel('Tempo')
plt.ylabel('Amplitude')
plt.title('Sinal de Tensão')
plt.legend()
plt.grid()
plt.show()

# Calcular a Transformada de Fourier
frequencia_amostragem = 1 / (tempo[1] - tempo[0])  # assumindo espaçamento constante
fft_sinalAzul = np.fft.fft(sinalAzul)
frequenciasAzul = np.fft.fftfreq(len(sinalAzul), d=1/frequencia_amostragem)
fft_sinalAmarelo = np.fft.fft(sinalAmarelo)
frequenciasAmarelo = np.fft.fftfreq(len(sinalAmarelo), d=1/frequencia_amostragem)

# Plotar a magnitude da Transformada de Fourier
plt.figure(figsize=(12, 5))
plt.plot(frequenciasAzul, np.abs(fft_sinalAzul), label='Transformada de Fourier azul', color = 'b')
plt.xlabel('Frequência (Hz)')
plt.ylabel('Magnitude')
plt.title('Espectro de Frequência')
plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(12, 5))
plt.plot(frequenciasAmarelo, np.abs(fft_sinalAmarelo), label='Transformada de Fourier amarelo', color = 'y')
plt.xlabel('Frequência (Hz)')
plt.ylabel('Magnitude')
plt.title('Espectro de Frequência')
plt.legend()
plt.grid()
plt.show()
